# %% [markdown]
# # *Hundir la flota*

# %%
import numpy as np
import pandas as pd

#Funcion para jugar o salir del juego

def crear_mapa():
    """
    Funcion para crear los mapas
    mapa1 y mapa2 serán los mapas mostrados sin los barcos
    mapa3 y mapa4 serán los mapas donde estarán los barcos
    """
    global mapa1
    mapa1 = list("≈")*100
    mapa1 = np.array(mapa1).reshape(10,10)
    
    global mapa2
    mapa2 = list("≈")*100
    mapa2 = np.array(mapa2).reshape(10,10)

    global mapa3
    mapa3 = list("≈")*100
    mapa3 = np.array(mapa3).reshape(10,10)
    
    global mapa4
    mapa4 = list("≈")*100
    mapa4 = np.array(mapa4).reshape(10,10)

#Funcion para posicionar los barcos

def barcos():

# MAPA 3

    #4 barcos de 1 posición de eslora
    numero_barcos = 4
    while numero_barcos > 0:
        x = np.random.randint(0, 10)
        y = np.random.randint(0, 10)
        if mapa3[x,y] != "≈":
            continue
        else:
            mapa3[x,y] = "O"
            numero_barcos -=1

    #3 barcos de 2 posiciones de eslora
    numero_barcos = 3
    while numero_barcos > 0:
        posicion = np.random.randint(0, 2)
        if posicion == 0: #horizontal
            x = np.random.randint(0, 10)
            y = np.random.randint(0, 9)
            z = y + 2
            if "O" in mapa3[x,y:z]:
                continue
            else:
                mapa3[x,y:z] = "O"
                numero_barcos -=1
        elif posicion == 1: #vertical
            x = np.random.randint(0, 9)
            y = np.random.randint(0, 10)
            z = x + 2
            if "O" in mapa3[x:z,y]:
                continue
            else:
                mapa3[x:z,y] = "O"
                numero_barcos -=1

    #2 barcos de 3 posiciones de eslora
    numero_barcos = 2
    while numero_barcos > 0:
        posicion = np.random.randint(0, 2)
        if posicion == 0: #horizontal
            x = np.random.randint(0, 10)
            y = np.random.randint(0, 8)
            z = y + 3
            if "O" in mapa3[x,y:z]:
                continue
            else:
                mapa3[x,y:z] = "O"
                numero_barcos -=1
        elif posicion == 1: #vertical
            x = np.random.randint(0, 8)
            y = np.random.randint(0, 10)
            z = x + 3
            if "O" in mapa3[x:z,y]:
                continue
            else:
                mapa3[x:z,y] = "O"
                numero_barcos -=1
    
    #1 barco de 4 posiciones de eslora
    numero_barcos = 1
    while numero_barcos > 0:
        posicion = np.random.randint(0, 2)
        if posicion == 0: #horizontal
            x = np.random.randint(0, 10)
            y = np.random.randint(0, 7)
            z = y + 4
            if "O" in mapa3[x,y:z]:
                continue
            else:
                mapa3[x,y:z] = "O"
                numero_barcos -=1
        elif posicion == 1: #vertical
            x = np.random.randint(0, 7)
            y = np.random.randint(0, 10)
            z = x + 4
            if "O" in mapa3[x:z,y]:
                continue
            else:
                mapa3[x:z,y] = "O"
                numero_barcos -=1

# MAPA 4

    #4 barcos de 1 posición de eslora
    numero_barcos = 4
    while numero_barcos > 0:
        x = np.random.randint(0, 10)
        y = np.random.randint(0, 10)
        if mapa4[x,y] != "≈":
            continue
        else:
            mapa4[x,y] = "O"
            numero_barcos -=1

    #3 barcos de 2 posiciones de eslora
    numero_barcos = 3
    while numero_barcos > 0:
        posicion = np.random.randint(0, 2)
        if posicion == 0: #horizontal
            x = np.random.randint(0, 10)
            y = np.random.randint(0, 9)
            z = y + 2
            if "O" in mapa4[x,y:z]:
                continue
            else:
                mapa4[x,y:z] = "O"
                numero_barcos -=1
        elif posicion == 1: #vertical
            x = np.random.randint(0, 9)
            y = np.random.randint(0, 10)
            z = x + 2
            if "O" in mapa4[x:z,y]:
                continue
            else:
                mapa4[x:z,y] = "O"
                numero_barcos -=1

    #2 barcos de 3 posiciones de eslora
    numero_barcos = 2
    while numero_barcos > 0:
        posicion = np.random.randint(0, 2)
        if posicion == 0: #horizontal
            x = np.random.randint(0, 10)
            y = np.random.randint(0, 8)
            z = y + 3
            if "O" in mapa4[x,y:z]:
                continue
            else:
                mapa4[x,y:z] = "O"
                numero_barcos -=1
        elif posicion == 1: #vertical
            x = np.random.randint(0, 8)
            y = np.random.randint(0, 10)
            z = x + 3
            if "O" in mapa4[x:z,y]:
                continue
            else:
                mapa4[x:z,y] = "O"
                numero_barcos -=1
    
    #1 barco de 4 posiciones de eslora
    numero_barcos = 1
    while numero_barcos > 0:
        posicion = np.random.randint(0, 2)
        if posicion == 0: #horizontal
            x = np.random.randint(0, 10)
            y = np.random.randint(0, 7)
            z = y + 4
            if "O" in mapa4[x,y:z]:
                continue
            else:
                mapa4[x,y:z] = "O"
                numero_barcos -=1
        elif posicion == 1: #vertical
            x = np.random.randint(0, 7)
            y = np.random.randint(0, 10)
            z = x + 4
            if "O" in mapa4[x:z,y]:
                continue
            else:
                mapa4[x:z,y] = "O"
                numero_barcos -=1


def imprime_mapa():
    print(pd.concat([d.reset_index(drop=True)for d in [
        pd.DataFrame(mapa1, columns=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]), 
        pd.DataFrame(mapa2, columns=["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"])]],
        keys= ["Tu", "Enemigo"], join="inner",axis=1))

#turno persona
def turno_persona():
    i = 1
    while True:
        if np.count_nonzero(mapa4 == "O") == 0:
            print("""
   ______                                   __       
  / ____/  ____ _   ____   ____ _   _____  / /_  ___ 
 / / __   / __ `/  / __ \ / __ `/  / ___/ / __/ / _\\
/ /_/ /  / /_/ /  / / / // /_/ /  (__  ) / /_  /  __/
\____/   \__,_/  /_/ /_/ \__,_/  /____/  \__/  \___/ 
                                                     
            Has hundido todos los barcos""")
            break
        elif np.count_nonzero(mapa4 == "O") == 0:
            print("Lo siento, no te quedan barcos")
            break
        else:
            print(f'[ Ronda {i} ]')
            imprime_mapa()
            ABC = input("Coordenada x")
            diccionario = {"A": 0, "B": 1, "C": 2, "D":3, "E": 4, "F":5, "G": 6, "H":7 , "I": 8, "J":9}
            yu = diccionario.get(ABC)
            xu = int(input("Coordenada y"))
            if mapa4[xu,yu] == "≈":
                mapa4[xu,yu] = " "
                mapa2[xu,yu] = " "
                print("AGUA")
                turno_ordenador()
            elif mapa4[xu,yu] == "O":
                mapa4[xu,yu] = "X"
                mapa2[xu,yu] = "X"
                print("TOCADO")
                turno_persona
            else:
                print("Selecciona una coordenada no seleccionada antes")
                pass
            i += 1

def turno_ordenador():
# turno ordenador
    xi = np.random.randint(0, 10)
    yi = np.random.randint(0, 10)
    if mapa3[xi,yi] == "≈":
        mapa3[xi,yi] = " "
        mapa1[xi,yi] = " "
        print("CPU AGUA")
    elif mapa3[xi,yi] == "O":
        mapa3[xi,yi] = "X"
        mapa1[xi,yi] = "X"
        print("CPU TOCADO")
        turno_ordenador()
    else:
        pass


def menu():

    mensaje_inicial ="""

██╗  ██╗██╗   ██╗███╗   ██╗██████╗ ██╗██████╗     ██╗      █████╗     ███████╗██╗      ██████╗ ████████╗ █████╗ 
██║  ██║██║   ██║████╗  ██║██╔══██╗██║██╔══██╗    ██║     ██╔══██╗    ██╔════╝██║     ██╔═══██╗╚══██╔══╝██╔══██╗
███████║██║   ██║██╔██╗ ██║██║  ██║██║██████╔╝    ██║     ███████║    █████╗  ██║     ██║   ██║   ██║   ███████║
██╔══██║██║   ██║██║╚██╗██║██║  ██║██║██╔══██╗    ██║     ██╔══██║    ██╔══╝  ██║     ██║   ██║   ██║   ██╔══██║
██║  ██║╚██████╔╝██║ ╚████║██████╔╝██║██║  ██║    ███████╗██║  ██║    ██║     ███████╗╚██████╔╝   ██║   ██║  ██║
╚═╝  ╚═╝ ╚═════╝ ╚═╝  ╚═══╝╚═════╝ ╚═╝╚═╝  ╚═╝    ╚══════╝╚═╝  ╚═╝    ╚═╝     ╚══════╝ ╚═════╝    ╚═╝   ╚═╝  ╚═╝

                Bienvenido a la batalla naval interectiva, ¿Dispuesto a derrotar a tu rival?

            Inserta A para Jugar
            Inserta Z para salir
                                                                                                                                                                                                                                             
"""
    print(mensaje_inicial)
    opciones()

def opciones():
    opcion = (input("Inserta option: "))
    if opcion == "A":
        crear_mapa()
        barcos()
        turno_persona()

    elif opcion == "Z":
        print("¡Gracias por usar el programa!")
    else:
        print("Solo acepta A y Z: ")
        opciones()

menu()
# Out:
# ██╗  ██╗██╗   ██╗███╗   ██╗██████╗ ██╗██████╗     ██╗      █████╗     ███████╗██╗      ██████╗ ████████╗ █████╗
# ██║  ██║██║   ██║████╗  ██║██╔══██╗██║██╔══██╗    ██║     ██╔══██╗    ██╔════╝██║     ██╔═══██╗╚══██╔══╝██╔══██╗
# ███████║██║   ██║██╔██╗ ██║██║  ██║██║██████╔╝    ██║     ███████║    █████╗  ██║     ██║   ██║   ██║   ███████║
# ██╔══██║██║   ██║██║╚██╗██║██║  ██║██║██╔══██╗    ██║     ██╔══██║    ██╔══╝  ██║     ██║   ██║   ██║   ██╔══██║
# ██║  ██║╚██████╔╝██║ ╚████║██████╔╝██║██║  ██║    ███████╗██║  ██║    ██║     ███████╗╚██████╔╝   ██║   ██║  ██║
# ╚═╝  ╚═╝ ╚═════╝ ╚═╝  ╚═══╝╚═════╝ ╚═╝╚═╝  ╚═╝    ╚══════╝╚═╝  ╚═╝    ╚═╝     ╚══════╝ ╚═════╝    ╚═╝   ╚═╝  ╚═╝
#
#                 Bienvenido a la batalla naval interectiva, ¿Dispuesto a derrotar a tu rival?
#
#             Inserta A para Jugar
#             Inserta Z para salir
#
#
# Solo acepta A y Z:
# Solo acepta A y Z:
# Solo acepta A y Z:
# Solo acepta A y Z:
# Solo acepta A y Z:
# ¡Gracias por usar el programa!
